# %%
import cv2
import math
import copy
import numpy as np
import matplotlib
from matplotlib import cm
import matplotlib.pyplot as plt
import scipy.ndimage.filters as filters

# %%
# import raw map for Bennu
Bennu_map = cv2.imread('Bennu_map.tif',0)
plt.imshow(Bennu_map, cmap = 'gray', extent=[0,360,-90,90])

# %%
# setting up coordinate system 
latitude_len  = np.shape(Bennu_map)[1] # length of latitude axis in pixels
longitude_len = np.shape(Bennu_map)[0] # length of longitude axis in pixels

# %%
plt.imshow(Bennu_map, cmap = 'gray', extent=[0,360,-90,90])
plt.plot(325.32, -74.95, 'o', linewidth=8, color='red', label = 'Jan 6 Near', alpha = 0.8)
plt.plot(343.67, -57.30, 'o', linewidth=8, color='blue', label = 'Jan 6 Far', alpha = 0.8)
plt.plot(335.40, 20.63, 'o', linewidth=8, color='magenta', label = 'Jan 19 OD', alpha = 0.8)
plt.plot(60.17, 20.68, 'o', linewidth=8, color='aqua', label = 'Feb 11 OD', alpha = 0.8)
plt.legend()
plt.show()
plt.savefig('Bennu_ejection.png', dpi=1000, bbox_inches='tight')
